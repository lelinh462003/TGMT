# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
dir = 'C:/Users/84397/Documents/TGMT/01/1.jpg'
#đọc ảnh và hiển thị
im = Image.open(dir)
#display(im)
plt.imshow(im)

# %%
#chuyển sang ảnh xám
im_gray = im.convert('L')
plt.imshow(im_gray, cmap='gray')

# %%
im_gray = np.array(im_gray)
print(im_gray)
# Out:
# [[ 14  14  14 ...  21  21  21]
#  [ 14  14  14 ...  21  21  21]
#  [ 14  14  14 ...  21  21  21]
#  ...
#  [159 159 160 ... 164 164 164]
#  [160 160 161 ... 164 164 164]
#  [161 161 162 ... 164 164 164]]

# %%
#tạo một hình vẽ mới
plt.figure()
plt.hist(im_array.flatten(), bins=128)
plt.xlabel('Gia trị của pixel')
plt.ylabel('số lượng')
plt.show()

# %%
# làm nổi bật đường biển
plt.figure()
plt.gray()
plt.contour(im_gray, origin="image")
plt.show()

# %%
# đường dẫn ảnh
dir = 'C:/Users/84397/Documents/TGMT/01/2.jpg'

# đọc ảnh và hiển thị ảnh với trục tọa độ
im = Image.open(dir).convert("L")

#hiển thị ảnh trên trục tọa độ
plt.imshow(im)

# tạo một hình vẽ mới
plt.figure()

#đặt màu sắc là xám
plt.gray()

#vẽ biểu đồ đường biên(contour) của ảnh 
plt.contour(im, origin="image")

# đảm bảo tỷ lệ x và trục y trên biểu đồ là bằng nhau
plt.axis('equal')

#hiển thị ảnh
plt.show()
